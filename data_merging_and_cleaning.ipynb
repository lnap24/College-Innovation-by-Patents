# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# access and mobility rates by college
# cross-sectional child income stats by college tier and parent income percentile
# cross sectional stats on children's income distribution by college tier
# highly selective college stats
# Longitudinal Statistics on Children’s Income Distributions by College Tier, Parent Income Ventile, and Cohort
# longitudinal_parent_child_income_dist_by_college_and_cohort

# %%
innovation = pd.read_csv('innovation_rates_by_college.csv')
innovation.rename(columns={'instnm':'college_name'}, inplace=True)
innovation.head()
# Out:
#    super_opeid                                       college_name  count  \
# 0            1  University Of Hawaii And Hawaii Community Coll...  27002
# 1            4                   Coast Community College District  24340
# 2           13  Kern & North Orange County Community College D...  18765
# 3           16        San Mateo County Community College District  10936
# 4           19         Foothill-Deanza Community College District  16619
#
#    count_pq1  count_pq2  count_pq3  count_pq4  count_pq5  inventor  \
# 0       3205       4527       5628       6957       6685  0.001037
# 1       4183       3829       4311       5066       6951  0.001643
# 2       2521       3091       3564       4410       5179  0.001119
# 3       1253       1658       2187       2513       3325  0.001646
# 4       2245       2287       2798       3206       6083  0.003189
#
#    inventor_pq1  inventor_pq2  inventor_pq3  inventor_pq4  inventor_pq5  \
# ...

# %%
innovation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   super_opeid    423 non-null    int64
#  1   college_name   423 non-null    object
#  2   count          423 non-null    int64
#  3   count_pq1      423 non-null    int64
#  4   count_pq2      423 non-null    int64
#  5   count_pq3      423 non-null    int64
#  6   count_pq4      423 non-null    int64
#  7   count_pq5      423 non-null    int64
#  8   inventor       423 non-null    float64
#  9   inventor_pq1   423 non-null    float64
#  10  inventor_pq2   423 non-null    float64
#  11  inventor_pq3   423 non-null    float64
#  12  inventor_pq4   423 non-null    float64
#  13  inventor_pq5   423 non-null    float64
#  14  top5cit        423 non-null    float64
#  15  total_patents  423 non-null    int64
#  16  total_cites    423 non-null    int64
# ...

# %%
soc_cap = pd.read_csv('social_capital_college.csv')
soc_cap.head()
# Out:
#    college                       college_name    zip  county  \
# 0   100200           Alabama A & M University  35762    1089
# 1   100300                Faulkner University  36109    1101
# 2   100400           University of Montevallo  35115    1117
# 3   100500           Alabama State University  36104    1101
# 4   100700  Central Alabama Community College  35010    1123
#
#    mean_students_per_cohort  ec_own_ses_college  ec_own_ses_se_college  \
# 0                943.666667             0.85678                0.02233
# 1                227.666667             1.30964                0.04869
# 2                494.000000             1.42378                0.03040
# 3                       NaN             0.77916                0.01937
# 4                       NaN             0.72742                0.03504
#
#    ec_parent_ses_college  ec_parent_ses_se_college  ec_high_own_ses_college  \
# 0                0.67629                   0.03241                  1.12202
# ...

# %%
soc_cap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2586 entries, 0 to 2585
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   college                        2586 non-null   int64
#  1   college_name                   2586 non-null   object
#  2   zip                            2586 non-null   int64
#  3   county                         2586 non-null   int64
#  4   mean_students_per_cohort       2097 non-null   float64
#  5   ec_own_ses_college             2362 non-null   float64
#  6   ec_own_ses_se_college          2362 non-null   float64
#  7   ec_parent_ses_college          2192 non-null   float64
#  8   ec_parent_ses_se_college       2192 non-null   float64
#  9   ec_high_own_ses_college        2362 non-null   float64
#  10  ec_high_own_ses_se_college     2362 non-null   float64
#  11  ec_high_parent_ses_college     2192 non-null   float64
# ...

# %%
merged_df = pd.merge(soc_cap, innovation, on='college_name', how='outer')
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2791 entries, 0 to 2790
# Data columns (total 38 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   college                        2586 non-null   float64
#  1   college_name                   2791 non-null   object
#  2   zip                            2586 non-null   float64
#  3   county                         2586 non-null   float64
#  4   mean_students_per_cohort       2097 non-null   float64
#  5   ec_own_ses_college             2362 non-null   float64
#  6   ec_own_ses_se_college          2362 non-null   float64
#  7   ec_parent_ses_college          2192 non-null   float64
#  8   ec_parent_ses_se_college       2192 non-null   float64
#  9   ec_high_own_ses_college        2362 non-null   float64
#  10  ec_high_own_ses_se_college     2362 non-null   float64
#  11  ec_high_parent_ses_college     2192 non-null   float64
# ...

# %%
college = pd.read_csv('college_level_characteristics.csv')
college
# Out:
#       super_opeid                                             name  region  \
# 0           30955  ASA Institute Of Business & Computer Technology       1
# 1            3537                     Abilene Christian University       3
# 2            1541             Abraham Baldwin Agricultural College       3
# 3            7531                        Academy Of Art University       4
# 4            1345                           Adams State University       4
# ...           ...                                              ...     ...
# 2458          208              Yosemite Community College District       4
# 2459         1604                             Young Harris College       3
# 2460         3145                      Youngstown State University       2
# 2461           42                  Yuba Community College District       4
# 2462         8133                               Zane State College       2
#
# ...

# %%
merged_df2 = pd.merge(merged_df, college, on='super_opeid', how='outer')
merged_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4831 entries, 0 to 4830
# Data columns (total 86 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   college                           2586 non-null   float64
#  1   college_name                      2791 non-null   object
#  2   zip_x                             2586 non-null   float64
#  3   county_x                          2586 non-null   float64
#  4   mean_students_per_cohort          2097 non-null   float64
#  5   ec_own_ses_college                2362 non-null   float64
#  6   ec_own_ses_se_college             2362 non-null   float64
#  7   ec_parent_ses_college             2192 non-null   float64
#  8   ec_parent_ses_se_college          2192 non-null   float64
#  9   ec_high_own_ses_college           2362 non-null   float64
#  10  ec_high_own_ses_se_college        2362 non-null   float64
# ...
