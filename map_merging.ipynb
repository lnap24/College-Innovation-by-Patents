# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
innovation = pd.read_csv("/Users/kendallscherer/DS4001G1P2/innovation_rates_by_college.csv")
innovation
# Out:
#      super_opeid                                             instnm  count  \
# 0              1  University Of Hawaii And Hawaii Community Coll...  27002
# 1              4                   Coast Community College District  24340
# 2             13  Kern & North Orange County Community College D...  18765
# 3             16        San Mateo County Community College District  10936
# 4             19         Foothill-Deanza Community College District  16619
# ..           ...                                                ...    ...
# 418        20662                                    New School, The   2691
# 419        20771                Milwaukee Institute Of Art & Design    640
# 420        20789                         Art Institute Of Colorado    2433
# 421        21415                 Savannah College Of Art And Design   4675
# 422        22913                          Art Institute Of Seattle    2616
#
# ...

# %%
coordinates = pd.read_csv("/Users/kendallscherer/DS4001G1P2/coordinates.csv")
coordinates
# Out:
#                  X             Y  OBJECTID  IPEDSID  \
# 0    -8.209134e+06  4.953591e+06         1   190752
# 1    -8.267688e+06  4.940383e+06         2   481429
# 2    -7.353945e+06  2.082890e+06         3   241739
# 3    -1.006191e+07  4.664997e+06         4   455071
# 4    -8.797220e+06  4.290711e+06         5   455141
# ...            ...           ...       ...      ...
# 6554 -9.317151e+06  5.308190e+06      6555   494889
# 6555 -1.082780e+07  4.536689e+06      6556   494898
# 6556 -8.145887e+06  4.983035e+06      6557   494904
# 6557 -1.304572e+07  3.865065e+06      6558   494913
# 6558 -1.270918e+07  5.819852e+06      6559   494922
#
#                                                    NAME  \
# 0     YESHIVA OF FAR ROCKAWAY DERECH AYSON RABBINICA...
# 1                          UNIVERSAL TRAINING INSTITUTE
# 2                UNIVERSIDAD ANA G. MENDEZ-CUPEY CAMPUS
# 3                                   HEALING ARTS CENTER
# ...

# %%
innovation['Name_lower'] = innovation['instnm'].str.lower()
coordinates['Name_lower'] = coordinates['NAME'].str.lower()

# Merge on the lowercase columns
merged_df = pd.merge(innovation, coordinates, on='Name_lower', how='inner')

# Drop the lowercase columns (if not needed)
#merged_df = merged_df.drop(columns=['Name_lower'])

merged_df
# Out:
#      super_opeid                               instnm  count  count_pq1  \
# 0            129                   Harvard University   6819        228
# 1           1009                    Auburn University  18709        658
# 2           1055  University Of Alabama In Huntsville   3061        243
# 3           1089             Arkansas Tech University   4612        679
# 4           1090            Arkansas State University   9055       1535
# ..           ...                                  ...    ...        ...
# 288        10149                Pepperdine University   2857        152
# 289        10684               Erie Community College  11930       1746
# 290        11649          Loyola Marymount University   5040        276
# 291        20771  Milwaukee Institute Of Art & Design    640         60
# 292        21415   Savannah College Of Art And Design   4675        253
#
#      count_pq2  count_pq3  count_pq4  count_pq5  inventor  inventor_pq1  ...  \
# ...

# %%
#just want innovation + lat + long + name??
columns = ['instnm','total_patents','LATITUDE','LONGITUDE','count']
merged_df_new = merged_df[columns]

# %%
merged_df_new
# Out:
#                                   instnm  total_patents   LATITUDE  \
# 0                     Harvard University            386  42.374172
# 1                      Auburn University            193  32.600201
# 2    University Of Alabama In Huntsville             20  34.722818
# 3               Arkansas Tech University             13  35.295227
# 4              Arkansas State University             36  35.843634
# ..                                   ...            ...        ...
# 288                Pepperdine University             26  34.041683
# 289               Erie Community College             12  42.881771
# 290          Loyola Marymount University             32  33.970855
# 291  Milwaukee Institute Of Art & Design            124  43.030917
# 292   Savannah College Of Art And Design            160  32.077439
#
#       LONGITUDE  count
# 0    -71.118234   6819
# 1    -85.492409  18709
# 2    -86.638420   3061
# 3    -93.132330   4612
# 4    -90.677872   9055
# ...

# %%
merged_df_new.to_csv('map_data2.csv', index=False)
